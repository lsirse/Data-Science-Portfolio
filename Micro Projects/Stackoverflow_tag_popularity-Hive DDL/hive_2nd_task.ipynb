# %%
# %%writefile query.hql
#
# USE stackoverflow_;
#
# DROP VIEW ranks_2009;
#
# CREATE VIEW ranks_2009(
#     rank, tag, amount
# ) AS SELECT rank() OVER (ORDER BY cnt.n DESC) as r, cnt.t, cnt.n FROM
#     (SELECT Count(e.T) as n, e.T as t FROM (
#         SELECT explode(Tags) as T
#     FROM posts
#     WHERE Year=2009 AND post_type_id=1
#     ) as e
#     GROUP BY e.T) as cnt
# ORDER by r ASC;
#
# DROP VIEW ranks_2016;
#
# CREATE VIEW ranks_2016(
#     rank, tag, amount
# ) AS SELECT rank() OVER (ORDER BY cnt.n DESC) as r, cnt.t, cnt.n FROM
#     (SELECT Count(e.T) as n, e.T as t FROM (
#         SELECT explode(Tags) as T
#     FROM posts
#     WHERE Year=2016 AND post_type_id=1
#     ) as e
#     GROUP BY e.T) as cnt
# ORDER by r ASC;
#
# SELECT ranks_2016.tag, ranks_2016.rank, ranks_2009.rank, ranks_2016.amount, ranks_2009.amount
# FROM ranks_2016
# INNER JOIN ranks_2009 ON ranks_2016.tag=ranks_2009.tag
# ORDER BY ranks_2016.rank ASC
# LIMIT 10;
# Out:
# Writing query.hql

# %%
! hive -f query.hql
# Out:
# Logging initialized using configuration in jar:file:/usr/local/apache-hive-1.1.0-bin/lib/hive-common-1.1.0.jar!/hive-log4j.properties
# OK
# Time taken: 1.124 seconds
# OK
# Time taken: 1.625 seconds
# OK
# Time taken: 1.801 seconds
# OK
# Time taken: 0.178 seconds
# OK
# Time taken: 0.141 seconds
# Query ID = jovyan_20180604133838_cb662548-068d-46eb-a9d5-abba683ccfb5
# Total jobs = 10
# Launching Job 1 out of 10
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1528070025954_0050, Tracking URL = http://e66087616de8:8088/proxy/application_1528070025954_0050/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1528070025954_0050
# Hadoop job information for Stage-1: number of mappers: 1; number of reducers: 1
# 2018-06-04 13:38:43,000 Stage-1 map = 0%,  reduce = 0%
# 2018-06-04 13:38:51,984 Stage-1 map = 100%,  reduce = 0%, Cumulative CPU 7.68 sec
# 2018-06-04 13:39:00,673 Stage-1 map = 100%,  reduce = 100%, Cumulative CPU 12.63 sec
# MapReduce Total cumulative CPU time: 12 seconds 630 msec
# Ended Job = job_1528070025954_0050
# Launching Job 2 out of 10
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1528070025954_0051, Tracking URL = http://e66087616de8:8088/proxy/application_1528070025954_0051/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1528070025954_0051
# Hadoop job information for Stage-6: number of mappers: 1; number of reducers: 1
# 2018-06-04 13:39:18,263 Stage-6 map = 0%,  reduce = 0%
# 2018-06-04 13:39:26,836 Stage-6 map = 100%,  reduce = 0%, Cumulative CPU 5.63 sec
# 2018-06-04 13:39:35,481 Stage-6 map = 100%,  reduce = 100%, Cumulative CPU 10.68 sec
# MapReduce Total cumulative CPU time: 10 seconds 680 msec
# Ended Job = job_1528070025954_0051
# Launching Job 3 out of 10
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1528070025954_0052, Tracking URL = http://e66087616de8:8088/proxy/application_1528070025954_0052/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1528070025954_0052
# Hadoop job information for Stage-2: number of mappers: 1; number of reducers: 1
# 2018-06-04 13:39:52,781 Stage-2 map = 0%,  reduce = 0%
# 2018-06-04 13:40:01,382 Stage-2 map = 100%,  reduce = 0%, Cumulative CPU 3.84 sec
# 2018-06-04 13:40:11,024 Stage-2 map = 100%,  reduce = 100%, Cumulative CPU 10.22 sec
# MapReduce Total cumulative CPU time: 10 seconds 220 msec
# Ended Job = job_1528070025954_0052
# Launching Job 4 out of 10
# Number of reduce tasks not specified. Estimated from input data size: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1528070025954_0053, Tracking URL = http://e66087616de8:8088/proxy/application_1528070025954_0053/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1528070025954_0053
# Hadoop job information for Stage-7: number of mappers: 1; number of reducers: 1
# 2018-06-04 13:40:28,169 Stage-7 map = 0%,  reduce = 0%
# 2018-06-04 13:40:35,660 Stage-7 map = 100%,  reduce = 0%, Cumulative CPU 3.31 sec
# 2018-06-04 13:40:45,287 Stage-7 map = 100%,  reduce = 100%, Cumulative CPU 9.76 sec
# MapReduce Total cumulative CPU time: 9 seconds 760 msec
# Ended Job = job_1528070025954_0053
# Launching Job 5 out of 10
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1528070025954_0054, Tracking URL = http://e66087616de8:8088/proxy/application_1528070025954_0054/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1528070025954_0054
# Hadoop job information for Stage-3: number of mappers: 1; number of reducers: 1
# 2018-06-04 13:41:02,676 Stage-3 map = 0%,  reduce = 0%
# 2018-06-04 13:41:11,274 Stage-3 map = 100%,  reduce = 0%, Cumulative CPU 3.96 sec
# 2018-06-04 13:41:19,797 Stage-3 map = 100%,  reduce = 100%, Cumulative CPU 8.14 sec
# MapReduce Total cumulative CPU time: 8 seconds 140 msec
# Ended Job = job_1528070025954_0054
# Launching Job 6 out of 10
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1528070025954_0055, Tracking URL = http://e66087616de8:8088/proxy/application_1528070025954_0055/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1528070025954_0055
# Hadoop job information for Stage-8: number of mappers: 1; number of reducers: 1
# 2018-06-04 13:41:37,346 Stage-8 map = 0%,  reduce = 0%
# 2018-06-04 13:41:44,873 Stage-8 map = 100%,  reduce = 0%, Cumulative CPU 3.75 sec
# 2018-06-04 13:41:53,395 Stage-8 map = 100%,  reduce = 100%, Cumulative CPU 7.36 sec
# MapReduce Total cumulative CPU time: 7 seconds 360 msec
# Ended Job = job_1528070025954_0055
# Stage-12 is selected by condition resolver.
# Stage-13 is filtered out by condition resolver.
# Stage-4 is filtered out by condition resolver.
# Execution log at: /tmp/jovyan/jovyan_20180604133838_cb662548-068d-46eb-a9d5-abba683ccfb5.log
# 2018-06-04 01:42:01	Starting to launch local task to process map join;	maximum memory = 477626368
# 2018-06-04 01:42:02	Dump the side-table for tag: 1 with group count: 2369 into file: file:/tmp/jovyan/ee10465c-08dd-47f5-8452-0e4f81a9fc40/hive_2018-06-04_13-38-26_808_7952014463084145003-1/-local-10010/HashTable-Stage-9/MapJoin-mapfile01--.hashtable
# 2018-06-04 01:42:03	Uploaded 1 File to: file:/tmp/jovyan/ee10465c-08dd-47f5-8452-0e4f81a9fc40/hive_2018-06-04_13-38-26_808_7952014463084145003-1/-local-10010/HashTable-Stage-9/MapJoin-mapfile01--.hashtable (76823 bytes)
# 2018-06-04 01:42:03	End of local task; Time Taken: 1.678 sec.
# Execution completed successfully
# MapredLocal task succeeded
# Launching Job 8 out of 10
# Number of reduce tasks is set to 0 since there's no reduce operator
# Starting Job = job_1528070025954_0056, Tracking URL = http://e66087616de8:8088/proxy/application_1528070025954_0056/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1528070025954_0056
# Hadoop job information for Stage-9: number of mappers: 1; number of reducers: 0
# 2018-06-04 13:42:15,176 Stage-9 map = 0%,  reduce = 0%
# 2018-06-04 13:42:22,689 Stage-9 map = 100%,  reduce = 0%, Cumulative CPU 3.84 sec
# MapReduce Total cumulative CPU time: 3 seconds 840 msec
# Ended Job = job_1528070025954_0056
# Launching Job 9 out of 10
# Number of reduce tasks determined at compile time: 1
# In order to change the average load for a reducer (in bytes):
#   set hive.exec.reducers.bytes.per.reducer=<number>
# In order to limit the maximum number of reducers:
#   set hive.exec.reducers.max=<number>
# In order to set a constant number of reducers:
#   set mapreduce.job.reduces=<number>
# Starting Job = job_1528070025954_0057, Tracking URL = http://e66087616de8:8088/proxy/application_1528070025954_0057/
# Kill Command = /opt/hadoop/bin/hadoop job  -kill job_1528070025954_0057
# Hadoop job information for Stage-5: number of mappers: 1; number of reducers: 1
# 2018-06-04 13:42:40,166 Stage-5 map = 0%,  reduce = 0%
# 2018-06-04 13:42:47,767 Stage-5 map = 100%,  reduce = 0%, Cumulative CPU 3.64 sec
# 2018-06-04 13:42:55,317 Stage-5 map = 100%,  reduce = 100%, Cumulative CPU 6.96 sec
# MapReduce Total cumulative CPU time: 6 seconds 960 msec
# Ended Job = job_1528070025954_0057
# MapReduce Jobs Launched:
# Stage-Stage-1: Map: 1  Reduce: 1   Cumulative CPU: 12.63 sec   HDFS Read: 832591 HDFS Write: 283234 SUCCESS
# Stage-Stage-6: Map: 1  Reduce: 1   Cumulative CPU: 10.68 sec   HDFS Read: 142687 HDFS Write: 67863 SUCCESS
# Stage-Stage-2: Map: 1  Reduce: 1   Cumulative CPU: 10.22 sec   HDFS Read: 289319 HDFS Write: 311766 SUCCESS
# Stage-Stage-7: Map: 1  Reduce: 1   Cumulative CPU: 9.76 sec   HDFS Read: 73950 HDFS Write: 74637 SUCCESS
# Stage-Stage-3: Map: 1  Reduce: 1   Cumulative CPU: 8.14 sec   HDFS Read: 315762 HDFS Write: 311766 SUCCESS
# Stage-Stage-8: Map: 1  Reduce: 1   Cumulative CPU: 7.36 sec   HDFS Read: 78633 HDFS Write: 74637 SUCCESS
# Stage-Stage-9: Map: 1   Cumulative CPU: 3.84 sec   HDFS Read: 316334 HDFS Write: 55844 SUCCESS
# Stage-Stage-5: Map: 1  Reduce: 1   Cumulative CPU: 6.96 sec   HDFS Read: 61096 HDFS Write: 188 SUCCESS
# Total MapReduce CPU Time Spent: 1 minutes 9 seconds 590 msec
# OK
# javascript	1	5	2771	192
# java	2	2	2033	243
# android	3	52	1809	25
# php	4	3	1673	215
# python	5	11	1585	108
# c#	6	1	1519	423
# html	7	14	1212	84
# jquery	8	8	1167	141
# ios	9	186	914	7
# css	10	20	801	59
# Time taken: 270.783 seconds, Fetched: 10 row(s)
